# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Read the files

# %%
data_train = pd.read_excel('Data_Train.xlsx')
data_test = pd.read_excel('Test_set.xlsx')
data_submission = pd.read_excel('Sample_submission.xlsx')

# %%
# Train Data
data_train.head(3)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882

# %%
data_test.head(3)
# Out:
#        Airline Date_of_Journey   Source Destination            Route Dep_Time  \
# 0  Jet Airways       6/06/2019    Delhi      Cochin  DEL → BOM → COK    17:30
# 1       IndiGo      12/05/2019  Kolkata    Banglore  CCU → MAA → BLR    06:20
# 2  Jet Airways      21/05/2019    Delhi      Cochin  DEL → BOM → COK    19:15
#
#    Arrival_Time Duration Total_Stops              Additional_Info
# 0  04:25 07 Jun  10h 55m      1 stop                      No info
# 1         10:20       4h      1 stop                      No info
# 2  19:00 22 May  23h 45m      1 stop  In-flight meal not included

# %%
data_submission.head(3)
# Out:
#    Price
# 0  15998
# 1  16612
# 2  25572

# %% [markdown]
# ### EDA

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
data_train.describe().T
# Out:
#          count         mean          std     min     25%     50%      75%  \
# Price  10683.0  9087.064121  4611.359167  1759.0  5277.0  8372.0  12373.0
#
#            max
# Price  79512.0

# %%
data_train.describe(include=object).T
# Out:
#                  count unique              top  freq
# Airline          10683     12      Jet Airways  3849
# Date_of_Journey  10683     44       18/05/2019   504
# Source           10683      5            Delhi  4537
# Destination      10683      6           Cochin  4537
# Route            10682    128  DEL → BOM → COK  2376
# Dep_Time         10683    222            18:55   233
# Arrival_Time     10683   1343            19:00   423
# Duration         10683    368           2h 50m   550
# Total_Stops      10682      5           1 stop  5625
# Additional_Info  10683     10          No info  8345

# %% [markdown]
# Inferences:
# 1. There is 1 data missing in route and total stops.
# 2. Out of 12 unique airlines Jet Airways is more frequent
# 3. For most of the airlines Source is delhi and destination is cochin
# 4. Most frequent route is Del->Bom->Cok
# 5. Most of the flights have 1 stop

# %%
# Visualization

# %%
t=1
plt.figure(figsize=(15,17))
for i in ['Airline','Source','Destination','Total_Stops','Additional_Info']:
    plt.subplot(3,2,t)
    sns.countplot(x=data_train[i])
    plt.xticks(rotation=45)
    t+=1
plt.plot()
plt.tight_layout()

# %% [markdown]
# ##### Key Observations and Recommendations:
# 1. **Duplicate Categories in Destination:**
# There are two categories for Delhi: "Delhi" and "New Delhi". These should be merged into a single category for consistency.
# 2. **Duplicate Categories in Additional Information:**
# There are two categories for additional information: "No info" and "No Info". These should also be merged into a single category to avoid redundancy.
#
# Jet Airways, Delhi, and Cochin dominate the airline, source, and destination distributions respectively.
# 1 stop flights are the most common, followed by non-stop flights.
# A significant portion of the dataset lacks additional info, with some indicating no in-flight meal or check-in baggage included.

# %% [markdown]
# ## Exploring Flight Routes:

# %%
data_train['Route'].value_counts().head(5).sum()
# Out:
# 6252

# %%
6252/data_train.shape[0]
# Out:
# 0.5852288682954226

# %%
data_train['Route'].value_counts().head(5).plot(kind='bar')
plt.xticks(rotation=30)
plt.show()

# %%
# Lets explore price column
sns.distplot(data_train['Price'])
plt.show()

# %%
# Lets explore price column
sns.boxplot(x=data_train['Price'])
plt.show()

# %% [markdown]
# Inferences:
# 1. There is 1 data missing in route and total stops.
# 2. Out of 12 unique airlines Jet Airways is more frequent
# 3. For most of the airlines Source is delhi and destination is cochin
# 4. Most frequent route is Del->Bom->Cok
# 5. Most of the flights have 1 stop
#
# Key observations:
# 1. There is duplicate category in destination Delhi and New Delhi.
# 2. There is duplicate category in Additional info, No info and No Info.
# 3. Top 5 routes have ~60% of data

# %%
# Bivariate Analysis
# Lets explore effect of airline on price

sns.boxplot(x=data_train['Airline'],y=data_train['Price'])
plt.xticks(rotation=30)
plt.show()

# %%
# Airline vs price (ANOVA, Krsukal-Wallis)

# %%
from scipy.stats import shapiro, jarque_bera,kruskal

# %%
# Assupmtion 1: The data comes from normal distribution

# Ho: The data is normal
# Ha: The data is not normal
shapiro(data_train['Price'])
# Out:
# ShapiroResult(statistic=0.8955856561660767, pvalue=0.0)

# %%
jarque_bera(data_train['Price'])
# Out:
# SignificanceResult(statistic=84545.14317610116, pvalue=0.0)

# %%
# The data is not normal

# %%
data_train['Airline'].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
# We have to go with Non parametric test Kruskal Wallis
# Ho: Airline has no affect on price
# Ha: Atleast one airline has different price

s1 = data_train[data_train['Airline']=='IndiGo']['Price']
s2 = data_train[data_train['Airline']=='Air India']['Price']
s3 = data_train[data_train['Airline']=='Jet Airways']['Price']
s4 = data_train[data_train['Airline']=='Multiple carriers']['Price']
s5 = data_train[data_train['Airline']=='GoAir']['Price']
s6 = data_train[data_train['Airline']=='Vistara']['Price']
s7 = data_train[data_train['Airline']=='Air Asia']['Price']
s8 = data_train[data_train['Airline']=='Vistara Premium economy']['Price']
s9 = data_train[data_train['Airline']=='Jet Airways Business']['Price']
s10 = data_train[data_train['Airline']=='Multiple carriers Premium economy']['Price']
s11= data_train[data_train['Airline']=='Trujet']['Price']
s12 = data_train[data_train['Airline']=='SpiceJet']['Price']

# %%
kruskal(s1,s2,s3,s4,s5,s6,s7,s8,s9,s10,s11,s12)
# Out:
# KruskalResult(statistic=4870.593769019019, pvalue=0.0)

# %%
# Lets explore effect of total_stops on price

sns.boxplot(x=data_train['Total_Stops'],y=data_train['Price'])
plt.xticks(rotation=30)
plt.show()

# %%
# Lets proove this fact statistically

data_train['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
sample = []
for i in ['non-stop', '2 stops', '1 stop', '3 stops']:
    s = data_train[data_train['Total_Stops']==i]['Price']
    sample.append(s)

# %%
kruskal(sample[0],sample[1],sample[2],sample[3])
# Out:
# KruskalResult(statistic=5749.236822864575, pvalue=0.0)

# %% [markdown]
# Inference:
# 1. Flight price is affectd by Airline and Total Stops

# %% [markdown]
# ## Data Preprocessing

# %%
# Combine the dataset
data = pd.concat([data_train,data_test],axis=0)

# %%
data.shape
# Out:
# (13354, 11)

# %%
# treat the missing values
data.isnull().sum()
# Out:
# Airline               0
# Date_of_Journey       0
# Source                0
# Destination           0
# Route                 1
# Dep_Time              0
# Arrival_Time          0
# Duration              0
# Total_Stops           1
# Additional_Info       0
# Price              2671
# dtype: int64

# %%
data[(data['Route'].isnull())|(data['Total_Stops'].isnull())]
# Out:
#         Airline Date_of_Journey Source Destination Route Dep_Time  \
# 9039  Air India       6/05/2019  Delhi      Cochin   NaN    09:45
#
#       Arrival_Time Duration Total_Stops Additional_Info   Price
# 9039  09:25 07 May  23h 40m         NaN         No info  7480.0

# %%
# We can drop this row
data.drop(index=[9039],inplace=True)

# %%
# Treat the outliers

# There are outliers in price but we decide to keep it in the data as it seems to be genuine.

# %%
data['Price'].max()
# Out:
# 79512.0

# %%
data[data['Price']==data['Price'].max()]
# Out:
#                    Airline Date_of_Journey    Source Destination  \
# 2924  Jet Airways Business      01/03/2019  Banglore   New Delhi
#
#                 Route Dep_Time Arrival_Time Duration Total_Stops  \
# 2924  BLR → BOM → DEL    05:45        11:25   5h 40m      1 stop
#
#      Additional_Info    Price
# 2924  Business class  79512.0

# %%
data[data['Airline']=='Jet Airways Business']['Price']
# Out:
# 657      52229.0
# 2924     79512.0
# 5372     62427.0
# 7351     46490.0
# 9715     52285.0
# 10364    57209.0
# 1802         NaN
# 1819         NaN
# Name: Price, dtype: float64

# %% [markdown]
# ### Feature Engineering
#
# * Generating some new feature using the exsiting ones.
# * Encoding category columns

# %% [markdown]
# ### Airline

# %%
map_airline = data_train['Airline'].value_counts(normalize=True).to_dict()

# %%
data['Airline'] = data['Airline'].map(map_airline)

# %%
data.head(3)
# Out:
#     Airline Date_of_Journey    Source Destination                  Route  \
# 0  0.192174      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1  0.163999       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  0.360292       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0

# %% [markdown]
# ### Date of journey

# %%
data['Date_of_Journey'] = pd.to_datetime(data['Date_of_Journey'],
                                        format='%d/%m/%Y')

# %%
data.head()
# Out:
#     Airline Date_of_Journey    Source Destination                  Route  \
# 0  0.192174      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1  0.163999      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  0.360292      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
# 3  0.192174      2019-05-12   Kolkata    Banglore        CCU → NAG → BLR
# 4  0.192174      2019-03-01  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0
# 3    18:05         23:30   5h 25m      1 stop         No info   6218.0
# 4    16:50         21:35   4h 45m      1 stop         No info  13302.0

# %%
data['Day_of_journey'] = data['Date_of_Journey'].dt.day
data['Month_of_Journey'] = data['Date_of_Journey'].dt.month
data['Weekday_of_Journey'] = data['Date_of_Journey'].dt.weekday

# %%
data.drop(columns=['Date_of_Journey'],inplace=True)

# %%
data.head(10)
# Out:
#     Airline    Source Destination                  Route Dep_Time  \
# 0  0.192174  Banglore   New Delhi              BLR → DEL    22:20
# 1  0.163999   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  0.360292     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3  0.192174   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4  0.192174  Banglore   New Delhi        BLR → NAG → DEL    16:50
# 5  0.076570   Kolkata    Banglore              CCU → BLR    09:00
# 6  0.360292  Banglore   New Delhi        BLR → BOM → DEL    18:55
# 7  0.360292  Banglore   New Delhi        BLR → BOM → DEL    08:00
# 8  0.360292  Banglore   New Delhi        BLR → BOM → DEL    08:55
# 9  0.111954     Delhi      Cochin        DEL → BOM → COK    11:25
#
#    Arrival_Time Duration Total_Stops              Additional_Info    Price  \
# 0  01:10 22 Mar   2h 50m    non-stop                      No info   3897.0
# 1         13:15   7h 25m     2 stops                      No info   7662.0
# 2  04:25 10 Jun      19h     2 stops                      No info  13882.0
# 3         23:30   5h 25m      1 stop                      No info   6218.0
# 4         21:35   4h 45m      1 stop                      No info  13302.0
# 5         11:25   2h 25m    non-stop                      No info   3873.0
# 6  10:25 13 Mar  15h 30m      1 stop  In-flight meal not included  11087.0
# 7  05:05 02 Mar   21h 5m      1 stop                      No info  22270.0
# 8  10:25 13 Mar  25h 30m      1 stop  In-flight meal not included  11087.0
# 9         19:15   7h 50m      1 stop                      No info   8625.0
#
#    Day_of_journey  Month_of_Journey  Weekday_of_Journey
# 0              24                 3                   6
# 1               1                 5                   2
# 2               9                 6                   6
# 3              12                 5                   6
# 4               1                 3                   4
# 5              24                 6                   0
# 6              12                 3                   1
# 7               1                 3                   4
# 8              12                 3                   1
# 9              27                 5                   0

# %% [markdown]
# ### Source and Destination

# %%
data['Source'].value_counts()
# Out:
# Source
# Delhi       5681
# Kolkata     3581
# Banglore    2752
# Mumbai       883
# Chennai      456
# Name: count, dtype: int64

# %%
data['Destination'].value_counts()
# Out:
# Destination
# Cochin       5681
# Banglore     3581
# Delhi        1582
# New Delhi    1170
# Hyderabad     883
# Kolkata       456
# Name: count, dtype: int64

# %%
data['Destination'] = data['Destination'].replace('New Delhi','Delhi')

# %%
data['Source_to_Destination'] = data['Source']+'-'+data['Destination']

# %%
data.head(3)
# Out:
#     Airline    Source Destination                  Route Dep_Time  \
# 0  0.192174  Banglore       Delhi              BLR → DEL    22:20
# 1  0.163999   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  0.360292     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
#
#    Arrival_Time Duration Total_Stops Additional_Info    Price  Day_of_journey  \
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897.0              24
# 1         13:15   7h 25m     2 stops         No info   7662.0               1
# 2  04:25 10 Jun      19h     2 stops         No info  13882.0               9
#
#    Month_of_Journey  Weekday_of_Journey Source_to_Destination
# 0                 3                   6        Banglore-Delhi
# 1                 5                   2      Kolkata-Banglore
# 2                 6                   6          Delhi-Cochin

# %%
map_sd = data[data['Price'].notnull()]['Source_to_Destination'].\
value_counts(normalize=True).to_dict()

# %%
data['Source_to_Destination'] = data['Source_to_Destination'].map(map_sd)

# %%
data.drop(columns=['Source','Destination'],inplace=True)

# %%
data.head()
# Out:
#     Airline                  Route Dep_Time  Arrival_Time Duration  \
# 0  0.192174              BLR → DEL    22:20  01:10 22 Mar   2h 50m
# 1  0.163999  CCU → IXR → BBI → BLR    05:50         13:15   7h 25m
# 2  0.360292  DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h
# 3  0.192174        CCU → NAG → BLR    18:05         23:30   5h 25m
# 4  0.192174        BLR → NAG → DEL    16:50         21:35   4h 45m
#
#   Total_Stops Additional_Info    Price  Day_of_journey  Month_of_Journey  \
# 0    non-stop         No info   3897.0              24                 3
# 1     2 stops         No info   7662.0               1                 5
# 2     2 stops         No info  13882.0               9                 6
# 3      1 stop         No info   6218.0              12                 5
# 4      1 stop         No info  13302.0               1                 3
#
#    Weekday_of_Journey  Source_to_Destination
# 0                   6               0.205673
# 1                   2               0.268770
# 2                   6               0.424640
# 3                   6               0.268770
# 4                   4               0.205673

# %% [markdown]
# ### Route

# %%
busy_routes = data_train['Route'].value_counts().head(5).index

# %%
busy_routes
# Out:
# Index(['DEL → BOM → COK', 'BLR → DEL', 'CCU → BOM → BLR', 'CCU → BLR',
#        'BOM → HYD'],
#       dtype='object', name='Route')

# %%
data['Route'] = data['Route'].apply(lambda r: 1 if r in busy_routes else 0)

# %%
data.head()
# Out:
#     Airline  Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0  0.192174      1    22:20  01:10 22 Mar   2h 50m    non-stop
# 1  0.163999      0    05:50         13:15   7h 25m     2 stops
# 2  0.360292      0    09:25  04:25 10 Jun      19h     2 stops
# 3  0.192174      0    18:05         23:30   5h 25m      1 stop
# 4  0.192174      0    16:50         21:35   4h 45m      1 stop
#
#   Additional_Info    Price  Day_of_journey  Month_of_Journey  \
# 0         No info   3897.0              24                 3
# 1         No info   7662.0               1                 5
# 2         No info  13882.0               9                 6
# 3         No info   6218.0              12                 5
# 4         No info  13302.0               1                 3
#
#    Weekday_of_Journey  Source_to_Destination
# 0                   6               0.205673
# 1                   2               0.268770
# 2                   6               0.424640
# 3                   6               0.268770
# 4                   4               0.205673

# %% [markdown]
# ### Dep Time and Arrival Time

# %% [raw]
# 4AM to 8AM -> Early Morning -> 0
# 8AM to 12Noon -> Morning -> 1
# 12Noon to 4PM -> Afternoon -> 2
# 4PM to 8PM -> Evening -> 3
# 8PM to 12AM -> Night -> 4
# 12AM to 4AM -> Late night ->5

# %%
data['Dep_Time'] = data['Dep_Time'].str.split(':',expand=True)[0].astype(int)

# %%
data['Arrival_Time'] = data['Arrival_Time'].str.split(':',expand=True)[0].astype(int)

# %%
data.head()
# Out:
#     Airline  Route  Dep_Time  Arrival_Time Duration Total_Stops  \
# 0  0.192174      1        22             1   2h 50m    non-stop
# 1  0.163999      0         5            13   7h 25m     2 stops
# 2  0.360292      0         9             4      19h     2 stops
# 3  0.192174      0        18            23   5h 25m      1 stop
# 4  0.192174      0        16            21   4h 45m      1 stop
#
#   Additional_Info    Price  Day_of_journey  Month_of_Journey  \
# 0         No info   3897.0              24                 3
# 1         No info   7662.0               1                 5
# 2         No info  13882.0               9                 6
# 3         No info   6218.0              12                 5
# 4         No info  13302.0               1                 3
#
#    Weekday_of_Journey  Source_to_Destination
# 0                   6               0.205673
# 1                   2               0.268770
# 2                   6               0.424640
# 3                   6               0.268770
# 4                   4               0.205673

# %%
def hour_to_cat(h):
    if h<=4:
        return 5
    elif h<=8:
        return 0
    elif h<=12:
        return 1
    elif h<=16:
        return 2
    elif h<=20:
        return 3
    else:
        return 4

# %%
data['Dep_Time'] = data['Dep_Time'].apply(hour_to_cat)
data['Arrival_Time'] = data['Arrival_Time'].apply(hour_to_cat)

# %%
data.head()
# Out:
#     Airline  Route  Dep_Time  Arrival_Time Duration Total_Stops  \
# 0  0.192174      1         4             5   2h 50m    non-stop
# 1  0.163999      0         0             2   7h 25m     2 stops
# 2  0.360292      0         1             5      19h     2 stops
# 3  0.192174      0         3             4   5h 25m      1 stop
# 4  0.192174      0         2             4   4h 45m      1 stop
#
#   Additional_Info    Price  Day_of_journey  Month_of_Journey  \
# 0         No info   3897.0              24                 3
# 1         No info   7662.0               1                 5
# 2         No info  13882.0               9                 6
# 3         No info   6218.0              12                 5
# 4         No info  13302.0               1                 3
#
#    Weekday_of_Journey  Source_to_Destination
# 0                   6               0.205673
# 1                   2               0.268770
# 2                   6               0.424640
# 3                   6               0.268770
# 4                   4               0.205673

# %% [markdown]
# ### Duration

# %%
data[['Dur_h','Dur_m']] = data['Duration'].str.split(expand=True)

# %%
data
# Out:
#        Airline  Route  Dep_Time  Arrival_Time Duration Total_Stops  \
# 0     0.192174      1         4             5   2h 50m    non-stop
# 1     0.163999      0         0             2   7h 25m     2 stops
# 2     0.360292      0         1             5      19h     2 stops
# 3     0.192174      0         3             4   5h 25m      1 stop
# 4     0.192174      0         2             4   4h 45m      1 stop
# ...        ...    ...       ...           ...      ...         ...
# 2666  0.163999      0         3             3  23h 55m      1 stop
# 2667  0.192174      1         2             2   2h 35m    non-stop
# 2668  0.360292      1         4             5   6h 35m      1 stop
# 2669  0.163999      1         5             3  15h 15m      1 stop
# 2670  0.111954      1         5             3  14h 20m      1 stop
#
#      Additional_Info    Price  Day_of_journey  Month_of_Journey  \
# 0            No info   3897.0              24                 3
# 1            No info   7662.0               1                 5
# 2            No info  13882.0               9                 6
# 3            No info   6218.0              12                 5
# 4            No info  13302.0               1                 3
# ...              ...      ...             ...               ...
# 2666         No info      NaN               6                 6
# 2667         No info      NaN              27                 3
# 2668         No info      NaN               6                 3
# 2669         No info      NaN               6                 3
# 2670         No info      NaN              15                 6
#
#       Weekday_of_Journey  Source_to_Destination Dur_h Dur_m
# 0                      6               0.205673    2h   50m
# 1                      2               0.268770    7h   25m
# 2                      6               0.424640   19h  None
# 3                      6               0.268770    5h   25m
# 4                      4               0.205673    4h   45m
# ...                  ...                    ...   ...   ...
# 2666                   3               0.268770   23h   55m
# 2667                   2               0.268770    2h   35m
# 2668                   2               0.424640    6h   35m
# 2669                   2               0.424640   15h   15m
# 2670                   5               0.424640   14h   20m
#
# [13353 rows x 14 columns]

# %%
data['Dur_h'].unique()
# Out:
# array(['2h', '7h', '19h', '5h', '4h', '15h', '21h', '25h', '13h', '12h',
#        '26h', '22h', '23h', '20h', '10h', '6h', '11h', '8h', '16h', '3h',
#        '27h', '1h', '14h', '9h', '18h', '17h', '24h', '30h', '28h', '29h',
#        '37h', '34h', '38h', '35h', '36h', '47h', '33h', '32h', '31h',
#        '42h', '39h', '5m', '41h', '40h'], dtype=object)

# %%
data[data['Duration']=='5m']
# Out:
#        Airline  Route  Dep_Time  Arrival_Time Duration Total_Stops  \
# 6474  0.163999      0         2             2       5m     2 stops
# 2660  0.163999      0         2             2       5m     2 stops
#
#      Additional_Info    Price  Day_of_journey  Month_of_Journey  \
# 6474         No info  17327.0               6                 3
# 2660         No info      NaN              12                 3
#
#       Weekday_of_Journey  Source_to_Destination Dur_h Dur_m
# 6474                   2                0.06525    5m  None
# 2660                   1                0.06525    5m  None

# %%
data['Dur_h'] = data['Dur_h'].str.rstrip('hm').astype(int)

# %%
data['Dur_m'].fillna('0',inplace=True)

# %%
data['Dur_m']=data['Dur_m'].str.rstrip('m').astype(int)

# %%
data['Duration'] = data['Dur_h']*60 + data['Dur_m']

# %%
data.drop(columns=['Dur_h','Dur_m'],inplace=True)

# %%
data.head()
# Out:
#     Airline  Route  Dep_Time  Arrival_Time  Duration Total_Stops  \
# 0  0.192174      1         4             5       170    non-stop
# 1  0.163999      0         0             2       445     2 stops
# 2  0.360292      0         1             5      1140     2 stops
# 3  0.192174      0         3             4       325      1 stop
# 4  0.192174      0         2             4       285      1 stop
#
#   Additional_Info    Price  Day_of_journey  Month_of_Journey  \
# 0         No info   3897.0              24                 3
# 1         No info   7662.0               1                 5
# 2         No info  13882.0               9                 6
# 3         No info   6218.0              12                 5
# 4         No info  13302.0               1                 3
#
#    Weekday_of_Journey  Source_to_Destination
# 0                   6               0.205673
# 1                   2               0.268770
# 2                   6               0.424640
# 3                   6               0.268770
# 4                   4               0.205673

# %% [markdown]
# ### Total_Stops

# %%
data['Total_Stops'] = data['Total_Stops'].str.split(expand=True)[0]

# %%
data['Total_Stops'] = np.where(data['Total_Stops']=='non-stop','0',data['Total_Stops'])

# %%
data['Total_Stops']= data['Total_Stops'].astype(int)

# %%
data['Total_Stops'].value_counts()
# Out:
# Total_Stops
# 1    7056
# 0    4340
# 2    1899
# 3      56
# 4       2
# Name: count, dtype: int64

# %% [markdown]
# ### Additional Info

# %%
data['Additional_Info'].value_counts()
# Out:
# Additional_Info
# No info                         10492
# In-flight meal not included      2426
# No check-in baggage included      396
# 1 Long layover                     20
# Change airports                     8
# Business class                      5
# No Info                             3
# 1 Short layover                     1
# Red-eye flight                      1
# 2 Long layover                      1
# Name: count, dtype: int64

# %%
data['Additional_Info'] = data['Additional_Info']\
.apply(lambda info: 0 if info in ['No info','No Info'] else 1)

# %% [markdown]
# ### Final data

# %%
data.head(10)
# Out:
#     Airline  Route  Dep_Time  Arrival_Time  Duration  Total_Stops  \
# 0  0.192174      1         4             5       170            0
# 1  0.163999      0         0             2       445            2
# 2  0.360292      0         1             5      1140            2
# 3  0.192174      0         3             4       325            1
# 4  0.192174      0         2             4       285            1
# 5  0.076570      1         1             1       145            0
# 6  0.360292      0         3             1       930            1
# 7  0.360292      0         0             0      1265            1
# 8  0.360292      0         0             1      1530            1
# 9  0.111954      1         1             3       470            1
#
#    Additional_Info    Price  Day_of_journey  Month_of_Journey  \
# 0                0   3897.0              24                 3
# 1                0   7662.0               1                 5
# 2                0  13882.0               9                 6
# 3                0   6218.0              12                 5
# 4                0  13302.0               1                 3
# 5                0   3873.0              24                 6
# 6                1  11087.0              12                 3
# 7                0  22270.0               1                 3
# 8                1  11087.0              12                 3
# 9                0   8625.0              27                 5
#
#    Weekday_of_Journey  Source_to_Destination
# 0                   6               0.205673
# 1                   2               0.268770
# 2                   6               0.424640
# 3                   6               0.268770
# 4                   4               0.205673
# 5                   0               0.268770
# 6                   1               0.205673
# 7                   4               0.205673
# 8                   1               0.205673
# 9                   0               0.424640

# %% [markdown]
# ## Train Test Split

# %%
train_set = data[data['Price'].notnull()]
test_set = data[data['Price'].isnull()]

# %%
train_set
# Out:
#         Airline  Route  Dep_Time  Arrival_Time  Duration  Total_Stops  \
# 0      0.192174      1         4             5       170            0
# 1      0.163999      0         0             2       445            2
# 2      0.360292      0         1             5      1140            2
# 3      0.192174      0         3             4       325            1
# 4      0.192174      0         2             4       285            1
# ...         ...    ...       ...           ...       ...          ...
# 10678  0.029861      1         3             4       150            0
# 10679  0.163999      1         3             4       155            0
# 10680  0.360292      1         0             1       180            0
# 10681  0.044838      1         1             2       160            0
# 10682  0.163999      0         1             3       500            2
#
#        Additional_Info    Price  Day_of_journey  Month_of_Journey  \
# 0                    0   3897.0              24                 3
# 1                    0   7662.0               1                 5
# 2                    0  13882.0               9                 6
# 3                    0   6218.0              12                 5
# 4                    0  13302.0               1                 3
# ...                ...      ...             ...               ...
# 10678                0   4107.0               9                 4
# 10679                0   4145.0              27                 4
# 10680                0   7229.0              27                 4
# 10681                0  12648.0               1                 3
# 10682                0  11753.0               9                 5
#
#        Weekday_of_Journey  Source_to_Destination
# 0                       6               0.205673
# 1                       2               0.268770
# 2                       6               0.424640
# 3                       6               0.268770
# 4                       4               0.205673
# ...                   ...                    ...
# 10678                   1               0.268770
# 10679                   5               0.268770
# 10680                   5               0.205673
# 10681                   4               0.205673
# 10682                   3               0.424640
#
# [10682 rows x 12 columns]

# %%
test_set.drop(columns=['Price'],inplace=True)
test_set
# Out:
#        Airline  Route  Dep_Time  Arrival_Time  Duration  Total_Stops  \
# 0     0.360292      1         3             5       655            1
# 1     0.192174      0         0             1       240            1
# 2     0.360292      1         3             3      1425            1
# 3     0.111954      1         0             4       780            1
# 4     0.029861      1         4             5       170            0
# ...        ...    ...       ...           ...       ...          ...
# 2666  0.163999      0         3             3      1435            1
# 2667  0.192174      1         2             2       155            0
# 2668  0.360292      1         4             5       395            1
# 2669  0.163999      1         5             3       915            1
# 2670  0.111954      1         5             3       860            1
#
#       Additional_Info  Day_of_journey  Month_of_Journey  Weekday_of_Journey  \
# 0                   0               6                 6                   3
# 1                   0              12                 5                   6
# 2                   1              21                 5                   1
# 3                   0              21                 5                   1
# 4                   0              24                 6                   0
# ...               ...             ...               ...                 ...
# 2666                0               6                 6                   3
# 2667                0              27                 3                   2
# 2668                0               6                 3                   2
# 2669                0               6                 3                   2
# 2670                0              15                 6                   5
#
#       Source_to_Destination
# 0                  0.424640
# 1                  0.268770
# 2                  0.424640
# 3                  0.424640
# 4                  0.205673
# ...                     ...
# 2666               0.268770
# 2667               0.268770
# 2668               0.424640
# 2669               0.424640
# 2670               0.424640
#
# [2671 rows x 11 columns]

# %%
# train test split on train_set

# %%
from sklearn.model_selection import train_test_split

# %%
y = train_set['Price']
x = train_set.drop(columns='Price')

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.8,random_state=2)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (8545, 11) (2137, 11) (8545,) (2137,)

# %% [markdown]
# ## Predictive Modeling

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import VotingRegressor,StackingRegressor

from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_percentage_error

# %% [raw]
# # Scoring parameter on Hackathon
#
# 1 - np.sqrt(np.square(np.log10(y_pred +1) - np.log10(y_true +1)).mean())

# %%
def hack_eval(y_true,y_pred):
    scor = 1 - np.sqrt(np.square(np.log10(y_pred +1) - np.log10(y_true +1)).mean())
    return scor

# %%
r2 = []
ms_error = []
rms_error = []
map_error = []
fit_model = []
hack_score = [] 

def model_evaluation(model,xtrain,ytrain,xtest,ytest):
    m = model
    m.fit(xtrain,ytrain)
    pred = m.predict(xtest)
    
    print('R2',r2_score(ytest,pred))
    print('MSE',mean_squared_error(ytest,pred))
    print('RMSE',np.sqrt(mean_squared_error(ytest,pred)))
    print('MAPE',mean_absolute_percentage_error(ytest,pred))
    print('Hack Score',hack_eval(ytest,pred))
    
    inp = input('Do you want to save this model? Y/N')
    if inp.lower()=='y':
        fit_model.append(str(m))
        r2.append(r2_score(ytest,pred))
        ms_error.append(mean_squared_error(ytest,pred))
        rms_error.append(np.sqrt(mean_squared_error(ytest,pred)))
        map_error.append(mean_absolute_percentage_error(ytest,pred))
        hack_score.append(hack_eval(ytest,pred))
        
        global score_card
        score_card = pd.DataFrame({'Model':fit_model,
                                  'R2':r2,
                                  'MSE':ms_error,
                                  'RMSE':rms_error,
                                  'MAPE':map_error,
                                  'Hachathon Score':hack_score})
    else:
        return

# %% [markdown]
# ### Linear Regression

# %%
model_evaluation(LinearRegression(),x_train,y_train,x_test,y_test)
# Out:
# R2 0.49605673287692165
# MSE 11209267.615819229
# RMSE 3348.024434770336
# MAPE 0.2717233415748301
# Hack Score 0.8522775848215686
# Do you want to save this model? Y/Ny

# %%
score_card
# Out:
#                 Model        R2           MSE         RMSE      MAPE  \
# 0  LinearRegression()  0.496057  1.120927e+07  3348.024435  0.271723
#
#    Hachathon Score
# 0         0.852278

# %% [markdown]
# ### Ridge and Lasso

# %%
model_evaluation(Ridge(alpha=0.1),x_train,y_train,x_test,y_test)
# Out:
# R2 0.4960527100753931
# MSE 11209357.095452834
# RMSE 3348.0377977933335
# MAPE 0.27171201865734346
# Hack Score 0.8523504298618133
# Do you want to save this model? Y/Ny

# %%
model_evaluation(Lasso(alpha=1),x_train,y_train,x_test,y_test)
# Out:
# R2 0.49608915179655044
# MSE 11208546.518089302
# RMSE 3347.9167430044167
# MAPE 0.27164738612046074
# Hack Score 0.839421780495631
# Do you want to save this model? Y/Ny

# %%
score_card
# Out:
#                 Model        R2           MSE         RMSE      MAPE  \
# 0  LinearRegression()  0.496057  1.120927e+07  3348.024435  0.271723
# 1    Ridge(alpha=0.1)  0.496053  1.120936e+07  3348.037798  0.271712
# 2      Lasso(alpha=1)  0.496089  1.120855e+07  3347.916743  0.271647
#
#    Hachathon Score
# 0         0.852278
# 1         0.852350
# 2         0.839422

# %% [markdown]
# ## Decision tree

# %%
model_evaluation(DecisionTreeRegressor(max_depth=9),
                x_train,y_train,x_test,y_test)
# Out:
# R2 0.7876658203773839
# MSE 4722973.3953247545
# RMSE 2173.24029856911
# MAPE 0.1272038948020981
# Hack Score 0.9182253055052759
# Do you want to save this model? Y/Ny

# %%
score_card
# Out:
#                                 Model        R2           MSE         RMSE  \
# 0                  LinearRegression()  0.496057  1.120927e+07  3348.024435
# 1                    Ridge(alpha=0.1)  0.496053  1.120936e+07  3348.037798
# 2                      Lasso(alpha=1)  0.496089  1.120855e+07  3347.916743
# 3  DecisionTreeRegressor(max_depth=9)  0.787666  4.722973e+06  2173.240299
#
#        MAPE  Hachathon Score
# 0  0.271723         0.852278
# 1  0.271712         0.852350
# 2  0.271647         0.839422
# 3  0.127204         0.918225

# %% [markdown]
# ### Random Forest

# %%
model_evaluation(RandomForestRegressor(n_estimators=100,max_depth=10),
                x_train,y_train,x_test,y_test)
# Out:
# R2 0.8451399361095995
# MSE 3444570.0784140276
# RMSE 1855.9553007586221
# MAPE 0.10044433274737512
# Hack Score 0.9336091454567716
# Do you want to save this model? Y/Ny

# %%
score_card
# Out:
#                                  Model        R2           MSE         RMSE  \
# 0                   LinearRegression()  0.496057  1.120927e+07  3348.024435
# 1                     Ridge(alpha=0.1)  0.496053  1.120936e+07  3348.037798
# 2                       Lasso(alpha=1)  0.496089  1.120855e+07  3347.916743
# 3   DecisionTreeRegressor(max_depth=9)  0.787666  4.722973e+06  2173.240299
# 4  RandomForestRegressor(max_depth=10)  0.845140  3.444570e+06  1855.955301
#
#        MAPE  Hachathon Score
# 0  0.271723         0.852278
# 1  0.271712         0.852350
# 2  0.271647         0.839422
# 3  0.127204         0.918225
# 4  0.100444         0.933609

# %% [markdown]
# ### AdaBoost

# %%
model_evaluation(AdaBoostRegressor(estimator=RandomForestRegressor(max_depth=3),n_estimators=200),
                x_train,y_train,x_test,y_test)
# Out:
# R2 0.2212715887126968
# MSE 17321344.944230087
# RMSE 4161.891990937545
# MAPE 0.5104707093783386
# Hack Score 0.7956185005081141
# Do you want to save this model? Y/Ny

# %%
score_card
# Out:
#                                                Model        R2           MSE  \
# 0                                 LinearRegression()  0.496057  1.120927e+07
# 1                                   Ridge(alpha=0.1)  0.496053  1.120936e+07
# 2                                     Lasso(alpha=1)  0.496089  1.120855e+07
# 3                 DecisionTreeRegressor(max_depth=9)  0.787666  4.722973e+06
# 4                RandomForestRegressor(max_depth=10)  0.845140  3.444570e+06
# 5  AdaBoostRegressor(estimator=RandomForestRegres...  0.221272  1.732134e+07
#
#           RMSE      MAPE  Hachathon Score
# 0  3348.024435  0.271723         0.852278
# 1  3348.037798  0.271712         0.852350
# 2  3347.916743  0.271647         0.839422
# 3  2173.240299  0.127204         0.918225
# 4  1855.955301  0.100444         0.933609
# 5  4161.891991  0.510471         0.795619

# %% [markdown]
# ### Gradient Boosting

# %%
model_evaluation(GradientBoostingRegressor(max_depth=7,n_estimators=150),
                x_train,y_train,x_test,y_test)
# Out:
# R2 0.882611247420199
# MSE 2611091.423576475
# RMSE 1615.887193951507
# MAPE 0.08942669147703083
# Hack Score 0.9409237694097051
# Do you want to save this model? Y/Ny

# %%
score_card
# Out:
#                                                Model        R2           MSE  \
# 0                                 LinearRegression()  0.496057  1.120927e+07
# 1                                   Ridge(alpha=0.1)  0.496053  1.120936e+07
# 2                                     Lasso(alpha=1)  0.496089  1.120855e+07
# 3                 DecisionTreeRegressor(max_depth=9)  0.787666  4.722973e+06
# 4                RandomForestRegressor(max_depth=10)  0.845140  3.444570e+06
# 5  AdaBoostRegressor(estimator=RandomForestRegres...  0.221272  1.732134e+07
# 6  GradientBoostingRegressor(max_depth=7, n_estim...  0.882611  2.611091e+06
#
#           RMSE      MAPE  Hachathon Score
# 0  3348.024435  0.271723         0.852278
# 1  3348.037798  0.271712         0.852350
# 2  3347.916743  0.271647         0.839422
# 3  2173.240299  0.127204         0.918225
# 4  1855.955301  0.100444         0.933609
# 5  4161.891991  0.510471         0.795619
# 6  1615.887194  0.089427         0.940924

# %% [markdown]
# ### XGBoost

# %%
model_evaluation(XGBRegressor(n_estimators=130,max_depth=8),
                x_train,y_train,x_test,y_test)
# Out:
# R2 0.882622747546876
# MSE 2610835.6249460597
# RMSE 1615.8080408718295
# MAPE 0.08386711553703896
# Hack Score 0.9402577411370484
# Do you want to save this model? Y/Ny

# %%
score_card
# Out:
#                                                Model        R2           MSE  \
# 0                                 LinearRegression()  0.496057  1.120927e+07
# 1                                   Ridge(alpha=0.1)  0.496053  1.120936e+07
# 2                                     Lasso(alpha=1)  0.496089  1.120855e+07
# 3                 DecisionTreeRegressor(max_depth=9)  0.787666  4.722973e+06
# 4                RandomForestRegressor(max_depth=10)  0.845140  3.444570e+06
# 5  AdaBoostRegressor(estimator=RandomForestRegres...  0.221272  1.732134e+07
# 6  GradientBoostingRegressor(max_depth=7, n_estim...  0.882611  2.611091e+06
# 7  XGBRegressor(base_score=None, booster=None, ca...  0.882623  2.610836e+06
#
#           RMSE      MAPE  Hachathon Score
# 0  3348.024435  0.271723         0.852278
# 1  3348.037798  0.271712         0.852350
# 2  3347.916743  0.271647         0.839422
# 3  2173.240299  0.127204         0.918225
# 4  1855.955301  0.100444         0.933609
# 5  4161.891991  0.510471         0.795619
# 6  1615.887194  0.089427         0.940924
# 7  1615.808041  0.083867         0.940258

# %% [markdown]
# ### Voting

# %%
base_models = [('DT',DecisionTreeRegressor(max_depth=10)),
              ('RF',RandomForestRegressor(n_estimators=130,max_depth=9)),
              ('GBR',GradientBoostingRegressor(max_depth=9,n_estimators=130)),
              ('XGBR',XGBRegressor(max_depth=8,n_estimators=130))]

# %%
model_evaluation(VotingRegressor(base_models),
                x_train,y_train,x_test,y_test)
# Out:
# R2 0.8645350800752785
# MSE 3013161.677226797
# RMSE 1735.8460983701284
# MAPE 0.09012116049005557
# Hack Score 0.938287562851235
# Do you want to save this model? Y/Ny

# %%
score_card
# Out:
#                                                Model        R2           MSE  \
# 0                                 LinearRegression()  0.496057  1.120927e+07
# 1                                   Ridge(alpha=0.1)  0.496053  1.120936e+07
# 2                                     Lasso(alpha=1)  0.496089  1.120855e+07
# 3                 DecisionTreeRegressor(max_depth=9)  0.787666  4.722973e+06
# 4                RandomForestRegressor(max_depth=10)  0.845140  3.444570e+06
# 5  AdaBoostRegressor(estimator=RandomForestRegres...  0.221272  1.732134e+07
# 6  GradientBoostingRegressor(max_depth=7, n_estim...  0.882611  2.611091e+06
# 7  XGBRegressor(base_score=None, booster=None, ca...  0.882623  2.610836e+06
# 8  VotingRegressor(estimators=[('DT', DecisionTre...  0.864535  3.013162e+06
#
#           RMSE      MAPE  Hachathon Score
# 0  3348.024435  0.271723         0.852278
# 1  3348.037798  0.271712         0.852350
# 2  3347.916743  0.271647         0.839422
# 3  2173.240299  0.127204         0.918225
# 4  1855.955301  0.100444         0.933609
# 5  4161.891991  0.510471         0.795619
# 6  1615.887194  0.089427         0.940924
# 7  1615.808041  0.083867         0.940258
# 8  1735.846098  0.090121         0.938288

# %% [markdown]
# ### Stacking

# %%
base_models = [('DT1',DecisionTreeRegressor(max_depth=10)),
               ('DT2',DecisionTreeRegressor(max_depth=9)),
              ('RF1',RandomForestRegressor(n_estimators=130,max_depth=9)),
               ('RF2',RandomForestRegressor(n_estimators=150,max_depth=8)),
              ('GBR',GradientBoostingRegressor(max_depth=9,n_estimators=130)),
              ('XGBR',XGBRegressor(max_depth=8,n_estimators=130))]

# %%
model_evaluation(StackingRegressor(estimators=base_models,final_estimator=(DecisionTreeRegressor(max_depth=5))),
                x_train,y_train,x_test,y_test)
# Out:
# R2 0.8584152728121377
# MSE 3149285.248757767
# RMSE 1774.622565155128
# MAPE 0.08728049724193378
# Hack Score 0.9390256694440817
# Do you want to save this model? Y/Ny

# %% [markdown]
# ### Final Score Card

# %%
score_card
# Out:
#                                                Model        R2           MSE  \
# 0                                 LinearRegression()  0.496057  1.120927e+07
# 1                                   Ridge(alpha=0.1)  0.496053  1.120936e+07
# 2                                     Lasso(alpha=1)  0.496089  1.120855e+07
# 3                 DecisionTreeRegressor(max_depth=9)  0.787666  4.722973e+06
# 4                RandomForestRegressor(max_depth=10)  0.845140  3.444570e+06
# 5  AdaBoostRegressor(estimator=RandomForestRegres...  0.221272  1.732134e+07
# 6  GradientBoostingRegressor(max_depth=7, n_estim...  0.882611  2.611091e+06
# 7  XGBRegressor(base_score=None, booster=None, ca...  0.882623  2.610836e+06
# 8  VotingRegressor(estimators=[('DT', DecisionTre...  0.864535  3.013162e+06
# 9  StackingRegressor(estimators=[('DT1', Decision...  0.858415  3.149285e+06
#
#           RMSE      MAPE  Hachathon Score
# 0  3348.024435  0.271723         0.852278
# 1  3348.037798  0.271712         0.852350
# 2  3347.916743  0.271647         0.839422
# 3  2173.240299  0.127204         0.918225
# 4  1855.955301  0.100444         0.933609
# 5  4161.891991  0.510471         0.795619
# 6  1615.887194  0.089427         0.940924
# 7  1615.808041  0.083867         0.940258
# 8  1735.846098  0.090121         0.938288
# 9  1774.622565  0.087280         0.939026

# %% [markdown]
# ### Lets tune XGBRegrssor

# %%
param = {'n_estimators':[130,150,170],
        'max_depth':[8,9,10,11,12],
        'gamma':[0,1]}

# %%
from sklearn.model_selection import GridSearchCV

# %%
gscv = GridSearchCV(estimator=XGBRegressor(),
                   param_grid=param,
                   scoring='r2',
                   verbose=3,
                   cv=5)

# %%
gscv.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV 1/5] END gamma=0, max_depth=8, n_estimators=130;, score=0.882 total time=   0.2s
# [CV 2/5] END gamma=0, max_depth=8, n_estimators=130;, score=0.882 total time=   0.1s
# [CV 3/5] END gamma=0, max_depth=8, n_estimators=130;, score=0.879 total time=   0.2s
# [CV 4/5] END gamma=0, max_depth=8, n_estimators=130;, score=0.852 total time=   0.2s
# [CV 5/5] END gamma=0, max_depth=8, n_estimators=130;, score=0.871 total time=   0.1s
# [CV 1/5] END gamma=0, max_depth=8, n_estimators=150;, score=0.881 total time=   0.2s
# [CV 2/5] END gamma=0, max_depth=8, n_estimators=150;, score=0.881 total time=   0.2s
# [CV 3/5] END gamma=0, max_depth=8, n_estimators=150;, score=0.877 total time=   0.2s
# [CV 4/5] END gamma=0, max_depth=8, n_estimators=150;, score=0.851 total time=   0.2s
# [CV 5/5] END gamma=0, max_depth=8, n_estimators=150;, score=0.870 total time=   0.2s
# [CV 1/5] END gamma=0, max_depth=8, n_estimators=170;, score=0.880 total time=   0.2s
# [CV 2/5] END gamma=0, max_depth=8, n_estimators=170;, score=0.881 total time=   0.2s
# [CV 3/5] END gamma=0, max_depth=8, n_estimators=170;, score=0.876 total time=   0.2s
# [CV 4/5] END gamma=1, max_depth=12, n_estimators=150;, score=0.840 total time=   0.8s
# [CV 5/5] END gamma=1, max_depth=12, n_estimators=150;, score=0.883 total time=   0.7s
# [CV 1/5] END gamma=1, max_depth=12, n_estimators=170;, score=0.878 total time=   0.7s
# [CV 2/5] END gamma=1, max_depth=12, n_estimators=170;, score=0.892 total time=   0.8s
# [CV 3/5] END gamma=1, max_depth=12, n_estimators=170;, score=0.898 total time=   0.9s
# [CV 4/5] END gamma=1, max_depth=12, n_estimators=170;, score=0.840 total time=   0.7s
# [CV 5/5] END gamma=1, max_depth=12, n_estimators=170;, score=0.883 total time=   0.7s
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     max_cat_threshold=None,
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=None, ...),
#              param_grid={'gamma': [0, 1], 'max_depth': [8, 9, 10, 11, 12],
#                          'n_estimators': [130, 150, 170]},
#              scoring='r2', verbose=3)

# %%
gscv.best_score_
# Out:
# 0.88372871576683

# %%
gscv.best_params_
# Out:
# {'gamma': 1, 'max_depth': 9, 'n_estimators': 130}

# %%
model_evaluation(XGBRegressor(**gscv.best_params_),
                x_train,y_train,x_test,y_test)
# Out:
# R2 0.8822142078464401
# MSE 2619922.8201377243
# RMSE 1618.6175645092094
# MAPE 0.08170316987363874
# Hack Score 0.9399745662887135
# Do you want to save this model? Y/Ny

# %%
score_card
# Out:
#                                                 Model        R2           MSE  \
# 0                                  LinearRegression()  0.496057  1.120927e+07
# 1                                    Ridge(alpha=0.1)  0.496053  1.120936e+07
# 2                                      Lasso(alpha=1)  0.496089  1.120855e+07
# 3                  DecisionTreeRegressor(max_depth=9)  0.787666  4.722973e+06
# 4                 RandomForestRegressor(max_depth=10)  0.845140  3.444570e+06
# 5   AdaBoostRegressor(estimator=RandomForestRegres...  0.221272  1.732134e+07
# 6   GradientBoostingRegressor(max_depth=7, n_estim...  0.882611  2.611091e+06
# 7   XGBRegressor(base_score=None, booster=None, ca...  0.882623  2.610836e+06
# 8   VotingRegressor(estimators=[('DT', DecisionTre...  0.864535  3.013162e+06
# 9   StackingRegressor(estimators=[('DT1', Decision...  0.858415  3.149285e+06
# 10  XGBRegressor(base_score=None, booster=None, ca...  0.882214  2.619923e+06
#
#            RMSE      MAPE  Hachathon Score
# 0   3348.024435  0.271723         0.852278
# 1   3348.037798  0.271712         0.852350
# 2   3347.916743  0.271647         0.839422
# 3   2173.240299  0.127204         0.918225
# 4   1855.955301  0.100444         0.933609
# 5   4161.891991  0.510471         0.795619
# 6   1615.887194  0.089427         0.940924
# 7   1615.808041  0.083867         0.940258
# 8   1735.846098  0.090121         0.938288
# 9   1774.622565  0.087280         0.939026
# 10  1618.617565  0.081703         0.939975

# %% [markdown]
# ### Fine Tune Random Forest

# %%
param = {'n_estimators':[120,150,170,200],
        'max_depth':[9,10,11]}

# %%
gscv = GridSearchCV(estimator=RandomForestRegressor(),
                   param_grid=param,
                   scoring='r2',
                   cv=5,verbose=3)

# %%
gscv.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5]
# [CV 4/5] END ....max_depth=10, n_estimators=200;, score=0.816 total time=   2.5s
# [CV 5/5] END ....max_depth=10, n_estimators=200;, score=0.854 total time=   2.5s
# [CV 1/5] END ....max_depth=11, n_estimators=120;, score=0.879 total time=   1.6s
# [CV 2/5] END ....max_depth=11, n_estimators=120;, score=0.860 total time=   1.6s
# [CV 3/5] END ....max_depth=11, n_estimators=120;, score=0.864 total time=   1.6s
# [CV 4/5] END ....max_depth=11, n_estimators=120;, score=0.825 total time=   1.6s
# [CV 5/5] END ....max_depth=11, n_estimators=120;, score=0.856 total time=   1.6s
# [CV 1/5] END ....max_depth=11, n_estimators=150;, score=0.880 total time=   1.9s
# [CV 2/5] END ....max_depth=11, n_estimators=150;, score=0.861 total time=   2.1s
# [CV 3/5] END ....max_depth=11, n_estimators=150;, score=0.863 total time=   2.1s
# [CV 4/5] END ....max_depth=11, n_estimators=150;, score=0.826 total time=   2.1s
# [CV 5/5] END ....max_depth=11, n_estimators=150;, score=0.860 total time=   2.1s
# [CV 1/5] END ....max_depth=11, n_estimators=170;, score=0.881 total time=   2.3s
# [CV 2/5] END ....max_depth=11, n_estimators=170;, score=0.857 total time=   2.4s
# [CV 3/5] END ....max_depth=11, n_estimators=170;, score=0.862 total time=   2.3s
# [CV 4/5] END ....max_depth=11, n_estimators=170;, score=0.825 total time=   2.3s
# [CV 5/5] END ....max_depth=11, n_estimators=170;, score=0.861 total time=   2.3s
# [CV 1/5] END ....max_depth=11, n_estimators=200;, score=0.876 total time=   2.7s
# [CV 2/5] END ....max_depth=11, n_estimators=200;, score=0.855 total time=   2.8s
# [CV 3/5] END ....max_depth=11, n_estimators=200;, score=0.866 total time=   2.7s
# [CV 4/5] END ....max_depth=11, n_estimators=200;, score=0.824 total time=   2.8s
# [CV 5/5] END ....max_depth=11, n_estimators=200;, score=0.858 total time=   2.8s
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [9, 10, 11],
#                          'n_estimators': [120, 150, 170, 200]},
#              scoring='r2', verbose=3)

# %%
gscv.best_score_
# Out:
# 0.857880395928942

# %%
gscv.best_params_
# Out:
# {'max_depth': 11, 'n_estimators': 150}

# %%
model_evaluation(RandomForestRegressor(**gscv.best_params_),
                x_train,y_train,x_test,y_test)
# Out:
# R2 0.8484722291936826
# MSE 3370449.502963006
# RMSE 1835.8784009195724
# MAPE 0.09267986895927406
# Hack Score 0.9363274485973423
# Do you want to save this model? Y/Ny

# %% [markdown]
# ### Stacking (Final Model)

# %%
base_models = [('DT1',DecisionTreeRegressor(max_depth=11)),
              ('RF1',RandomForestRegressor(max_depth=11,n_estimators=170)),
              ('GBR',GradientBoostingRegressor(max_depth=9,n_estimators=130)),
              ('XGBR',XGBRegressor(max_depth=8,n_estimators=130))]

# %%
model_evaluation(StackingRegressor(estimators=base_models),
                x_train,y_train,x_test,y_test)
# Out:
# R2 0.882616257129849
# MSE 2610979.9920328707
# RMSE 1615.8527135951688
# MAPE 0.07988535151572895
# Hack Score 0.9425258415417083
# Do you want to save this model? Y/Ny

# %%
score_card
# Out:
#                                                 Model        R2           MSE  \
# 0                                  LinearRegression()  0.496057  1.120927e+07
# 1                                    Ridge(alpha=0.1)  0.496053  1.120936e+07
# 2                                      Lasso(alpha=1)  0.496089  1.120855e+07
# 3                  DecisionTreeRegressor(max_depth=9)  0.787666  4.722973e+06
# 4                 RandomForestRegressor(max_depth=10)  0.845140  3.444570e+06
# 5   AdaBoostRegressor(estimator=RandomForestRegres...  0.221272  1.732134e+07
# 6   GradientBoostingRegressor(max_depth=7, n_estim...  0.882611  2.611091e+06
# 7   XGBRegressor(base_score=None, booster=None, ca...  0.882623  2.610836e+06
# 8   VotingRegressor(estimators=[('DT', DecisionTre...  0.864535  3.013162e+06
# 9   StackingRegressor(estimators=[('DT1', Decision...  0.858415  3.149285e+06
# 10  XGBRegressor(base_score=None, booster=None, ca...  0.882214  2.619923e+06
# 11  RandomForestRegressor(max_depth=11, n_estimato...  0.848472  3.370450e+06
# 12  StackingRegressor(estimators=[('DT1', Decision...  0.882616  2.610980e+06
#
#            RMSE      MAPE  Hachathon Score
# 0   3348.024435  0.271723         0.852278
# 1   3348.037798  0.271712         0.852350
# 2   3347.916743  0.271647         0.839422
# 3   2173.240299  0.127204         0.918225
# 4   1855.955301  0.100444         0.933609
# 5   4161.891991  0.510471         0.795619
# 6   1615.887194  0.089427         0.940924
# 7   1615.808041  0.083867         0.940258
# 8   1735.846098  0.090121         0.938288
# 9   1774.622565  0.087280         0.939026
# 10  1618.617565  0.081703         0.939975
# 11  1835.878401  0.092680         0.936327
# 12  1615.852714  0.079885         0.942526

# %% [markdown]
# ## Hackathon Submission

# %%
data_submission
# Out:
#       Price
# 0     15998
# 1     16612
# 2     25572
# 3     25778
# 4     16934
# ...     ...
# 2666  14046
# 2667  14086
# 2668  22720
# 2669  23544
# 2670  27489
#
# [2671 rows x 1 columns]

# %%
y
# Out:
# 0         3897.0
# 1         7662.0
# 2        13882.0
# 3         6218.0
# 4        13302.0
#           ...
# 10678     4107.0
# 10679     4145.0
# 10680     7229.0
# 10681    12648.0
# 10682    11753.0
# Name: Price, Length: 10682, dtype: float64

# %%
final_model = StackingRegressor(estimators=base_models)

# %%
final_model.fit(x,y)
# Out:
# StackingRegressor(estimators=[('DT1', DecisionTreeRegressor(max_depth=11)),
#                               ('RF1',
#                                RandomForestRegressor(max_depth=11,
#                                                      n_estimators=170)),
#                               ('GBR',
#                                GradientBoostingRegressor(max_depth=9,
#                                                          n_estimators=130)),
#                               ('XGBR',
#                                XGBRegressor(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=None, device=None,
#                                             early_s...
#                                             grow_policy=None,
#                                             importance_type=None,
#                                             interaction_constraints=None,
#                                             learning_rate=None, max_bin=None,
#                                             max_cat_threshold=None,
#                                             max_cat_to_onehot=None,
#                                             max_delta_step=None, max_depth=8,
#                                             max_leaves=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             multi_strategy=None,
#                                             n_estimators=130, n_jobs=None,
#                                             num_parallel_tree=None,
#                                             random_state=None, ...))])

# %%
final_pred = final_model.predict(test_set)

# %%
len(final_pred)
# Out:
# 2671

# %%
final_submission = pd.DataFrame({'Price':final_pred})

# %%
final_submission
# Out:
#              Price
# 0     14269.934612
# 1      4262.813386
# 2     13001.481825
# 3     11805.369005
# 4      3743.090926
# ...            ...
# 2666   9629.445452
# 2667   4598.092163
# 2668  16769.592536
# 2669  13712.142980
# 2670   8075.544203
#
# [2671 rows x 1 columns]

# %%
final_submission.to_excel('final_submission.xlsx',index=False)
